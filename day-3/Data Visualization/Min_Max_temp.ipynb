# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('min_max_temp.csv')

# %%
data.set_index('Date', inplace=True)

# %%
data
# Out:
#             Year  Month  Day  ... Dir of Max Gust Flag  Max_gust Spd of Max Gust Flag
# Date                          ...
# 2017-01-01  2017      1    1  ...                  NaN        54                  NaN
# 2017-01-02  2017      1    2  ...                  NaN       <31                  NaN
# 2017-01-03  2017      1    3  ...                  NaN        43                  NaN
# 2017-01-04  2017      1    4  ...                  NaN        85                  NaN
# 2017-01-05  2017      1    5  ...                  NaN        76                  NaN
# ...          ...    ...  ...  ...                  ...       ...                  ...
# 2017-12-27  2017     12   27  ...                  NaN        37                  NaN
# 2017-12-28  2017     12   28  ...                  NaN        44                  NaN
# 2017-12-29  2017     12   29  ...                  NaN        30                  NaN
# 2017-12-30  2017     12   30  ...                  NaN       <31                  NaN
# 2017-12-31  2017     12   31  ...                  NaN        37                  NaN
#
# [365 rows x 26 columns]

# %%
max_temps = data['Tmax']
min_temps = data['Tmin']

# %%
plt.figure()
data['Tmax'].plot(color='red', figsize=[8,5])

# %%
plt.figure()
data['Tmin'].plot(color='orange', figsize=[8,5])

# %%
plt.figure()
data['Tmax'].plot(color='red', figsize=[8,5])
data['Tmin'].plot(color='blue')
